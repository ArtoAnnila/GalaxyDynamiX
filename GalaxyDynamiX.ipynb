# %% [markdown]
# # **GalaxyDynamiX**
#
# **Usage**
# 1. (Optional) Mount Google Drive in Cell 1 if you want to save figures.
# 2. Edit the `── USER CONFIG ──` block at the top of Cell 2 to choose:
#    - which system types to plot (`PLOT_*` flags)
#    - which spiral density profile to use (`SPIRAL_PROFILE`)
#    - whether to overlay observed data points (`SHOW_DATA`)
#    - axis limits, scales, and output filename
# 3. Run Cell 2 — all profiles and the figure are produced automatically.
# 4. Cell 3 plots density and acceleration profiles (diagnostic).
# 5. Cell 4 plots the flux-balance overdensity blow-up.
# 6. Cell 5 plots the cosmic density–time diagram.

# %%
#@title MOUNT (optional – needed only to save figures to Drive)
from google.colab import drive
drive.mount("/content/gdrive")
path = "/content/gdrive/MyDrive/ColabMaps/"
# Out:
# Mounted at /content/gdrive

# %%
#@title VELOCITY DISPERSIONS AND ROTATION CURVES
# GalaxyDynamiX: velocity dispersions and rotation curves
# including the acceleration effect of cosmic expansion.

import math, numpy as np, matplotlib.pyplot as plt
from scipy.special import gammaincinv
from scipy.integrate import quad

plt.rcParams['font.family'] = 'DejaVu Serif'

# ════════════════════════════════════════════════════════════════════════════════
# ── USER CONFIG ─────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════

# -- Which system types to include in the plot --
PLOT_CLUSTER  = True   # Galaxy cluster  (Hernquist, blue)
PLOT_ELLIP    = True   # Elliptical galaxy (Hernquist, green)
PLOT_DWARF    = True   # Dwarf spheroidal  (Hernquist, red)
PLOT_SPIRAL   = True   # Spiral galaxy rotation curve (black/gray)

# -- Spiral density profile (used when PLOT_SPIRAL = True) --
#    "exp"   : exponential disk  Σ∝exp(-R/R_d)       [recommended; van der Kruit 1981]
#    "sersic": projected Sérsic  (originally in code)
#    "MN"    : Miyamoto–Nagai 3-D disk
SPIRAL_PROFILE = "exp"

# -- Overlay observed data points --
SHOW_DATA = True       # True → plot tabulated galaxy data points

# -- Galaxy to overlay (used when SHOW_DATA = True and PLOT_SPIRAL = True) --
#    Options: "NGC 3198", "NGC 6503", "NGC 2403"
#    (add more entries to GALAXY_DATA below)
SPIRAL_DATA_GALAXY = "NGC 3198"   # also try "NGC 6503", "NGC 2403"

# -- Plot axes --
XSCALE  = "log"        # "log" or "linear"
YSCALE  = "log"        # "log" or "linear"
XLIM    = (1e2, 2e7)   # light-years
YLIM    = (1, 2000)    # km/s

# -- Save figure (set to None to skip, or provide a filename string) --
path     = "/content/gdrive/MyDrive/ColabMaps/"   # Drive path (Cell 1 must be run)
FILENAME = "TFFJ.jpg"  # e.g. "TFFJ.jpg"

# ── SYSTEM PARAMETERS ──────────────────────────────────────────────────────────

# Cluster (Hernquist) — baryonic (gas + stellar) mass
# Coma baryonic mass ~ 1e14 Msun
# Note, conventional 1e15 includes inferred dark matter
M_cluster_solar = 1e14          # baryonic mass [M☉]
r_cluster_ly    = 1e6           # Hernquist scale radius [ly]

# Elliptical galaxy (Hernquist)
M_ellip_solar   = 3e10
r_ellip_ly      = 3_000

# Dwarf spheroidal (Hernquist)
M_dwarf_solar   = 2e6
r_dwarf_ly      = 1000

# Spiral galaxy – exponential disk (SPIRAL_PROFILE = "exp")
M_exp_solar     = 3e10          # total disk mass [M☉]
R_d_ly          = 10_000        # radial scale length [ly]

# Spiral galaxy – Sérsic (SPIRAL_PROFILE = "sersic")
M_ser_solar     = 4e10
R_e_ser_ly      = 20_000        # effective radius
n_ser           = 1.0

# Spiral galaxy – Miyamoto–Nagai (SPIRAL_PROFILE = "MN")
M_MN_solar      = 4e10
a_MN_ly         = 10_000         # radial scale
b_MN_ly         = 1000           # vertical scale

# ── NOTE ON MASSES ────────────────────────────────────────────────────────────
# Literature "dynamical masses" for clusters and dwarfs are inferred by applying
# the Newtonian virial theorem to observed velocity dispersions — i.e. they already
# include the cosmic acceleration a_R as if it were dark matter. In this model,
# only the *baryonic* mass drives the local Newtonian term; a_R is supplied by the
# cosmic flux. Therefore the correct input here is the baryonic (stellar + gas) mass,
# which is substantially lower than the conventional dynamical mass.
# ─────────────────────────────────────────────────────────────────────────────
# Environment / density-balance parameters
M_env   = 1e15 * 1.98847e30   # in a cluster environment mass [kg]
df      = 1                   # density factor at boundary

# ════════════════════════════════════════════════════════════════════════════════
# ── OBSERVED DATA (rotation curves & velocity dispersions) ─────────────────────
# ── Add or extend entries freely; units: r in ly, v/sigma in km/s ──────────────
# ════════════════════════════════════════════════════════════════════════════════

GALAXY_DATA = {

    # ── Spiral rotation curves ──────────────────────────────────────────────
    # Source: Begeman (1989), A&A 223, 47  (HI 21-cm synthesis)
    "NGC 3198": {
        "type": "spiral",
        "ref": "Begeman 1989",
        "data": [   # (r [ly],  v [km/s])
            (2446, 76),   (4892, 107),  (7339, 130),  (9785, 138),
            (13046, 148), (16308, 149), (19569, 151), (24462, 151),
            (29354, 152), (34246, 149), (39139, 151), (45662, 149),
            (52185, 149), (58708, 151), (65231, 150), (71754, 151),
            (81539, 150), (91324, 147), (97847, 148),
        ],
    },

    # Source: de Blok & McGaugh (1997); Begeman (1987 thesis)
    #"NGC 6503": {
    #    "type": "spiral",
    #    "ref": "Begeman 1987 / de Blok & McGaugh 1997",
    #    "data": [
    #        (652, 25),    (1631, 48),   (3262, 73),   (4892, 89),
    #        (6523, 97),   (8154, 103),  (9785, 108),  (13046, 112),
    #        (16308, 115), (19569, 115), (22831, 116), (26092, 116),
    #        (29354, 117), (32616, 117), (35877, 116), (39139, 116),
    #    ],
    #},

    # Source: Begeman (1989); de Blok & McGaugh (1997)
    #"NGC 2403": {
    #    "type": "spiral",
    #    "ref": "Begeman 1989",
    #    "data": [
    #        (1631, 53),   (3262, 89),   (4892, 106),  (6523, 116),
    #        (8154, 121),  (9785, 122),  (13046, 127), (16308, 130),
    #        (21200, 131), (26092, 132), (30985, 131), (35877, 132),
    #        (40770, 130), (45662, 131), (52185, 128),
    #    ],
    #},

    # ── Elliptical galaxies – velocity dispersion profiles ──────────────────
    # NGC 4697: round E6, well-studied with PNe; Méndez et al. (2001)
    # r in ly (~1 kpc = 3262 ly), sigma in km/s (approximate binned profiles)
    #"NGC 3379": {
    #    "type": "elliptical",
    #    "ref": "Romanowsky et al. 2003",
    #    "data": [
    #        (4000, 200),
    #        (8000, 150),
    #        (12000, 110),
    #        (16000, 80),
    #        (24000, 60),
    #        (32000, 45),
    #    ],
    #},
    #"NGC 7507": {
    #    "type": "elliptical",
    #    "ref": "Salinas et al. 2012",
    #    "data": [
    #        (734, 240), (1835, 228), (3669, 210), (7339, 185),
    #        (11008, 165), (16512, 140), (22016, 120), (27519, 108), (33023, 98),
    #    ],
    #},
    #"NGC 4697": {
    #    "type": "elliptical",
    #    "ref": "Méndez et al. 2001",
    #    "data": [
    #        (4000, 160), (8000, 130), (12000, 110), (16000, 90),
    #        (24000, 70), (32000, 55), (40000, 45),
    #    ],
    #},

    "NGC 4697": {
    "type": "elliptical",
    "ref": "Méndez et al. 2001; Méndez et al. 2009",
    "data": [
        # r [ly],  sigma [km/s]
        (4000,  170),   # ~0.3 Re
        (8000,  150),   # ~0.7 Re
        (12000, 135),   # ~1.0 Re
        (18000, 120),   # ~1.5 Re
        (24000, 110),   # ~2.0 Re
        (32000, 100),   # ~2.7 Re
        (40000,  95),   # ~3.3 Re
        (52000,  90),   # ~4.3 Re
        ],
    },

    # ── Dwarf spheroidals – integrated velocity dispersion ──────────────────
    # Sculptor dSph: Walker et al. (2009), Table 1 – binned line-of-sight sigma profile
    # Stellar mass ~ 2–4×10^6 Msun (Woo et al. 2008); half-light r ~ 280 pc = 913 ly
    "Sculptor dSph": {
        "type": "dwarf",
        "ref": "Walker et al. 2009",
        "data": [
            (163,  9.2), (326, 9.0), (652, 8.8), (978, 8.5),
            (1304, 7.8), (1631, 6.9),
        ],
    },

    # Draco: Walker et al. (2009)
    "Draco dSph": {
        "type": "dwarf",
        "ref": "Walker et al. 2009",
        "data": [
            (163, 10.1), (326, 9.8), (489, 9.5), (652, 9.1),
            (815, 8.4),  (978, 7.5),
        ],
    },

    # ── Galaxy clusters – projected velocity dispersion ──────────────────────
    # Coma cluster: Colless & Dunn (1996), projected velocity dispersion profile
    # Baryonic (gas + stellar) mass ~ 1e14 Msun; remainder conventionally attributed to DM
    "Coma cluster": {
        "type": "cluster",
        "ref": "Colless & Dunn 1996",
        "data": [
            (163000, 980), (326000, 950), (652000, 910), (978000, 895),
            (1304000, 870), (1956000, 840), (3261560, 780),
        ],
    },
}

# ════════════════════════════════════════════════════════════════════════════════
# ── CONSTANTS ──────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════

G       = 6.67430e-11
c       = 299792458
M_sun   = 1.98847e30
ly_m    = 9.461e15          # 1 ly in metres
pc_m    = 3.0857e16         # 1 pc in metres
ly_pc   = 0.306601          # 1 ly in parsecs

t_H    = 13.8e9 * 365.25 * 24 * 3600   # Hubble time [s]
R_H    = c * t_H                         # causal radius [m]
a_R    = c / t_H                         # cosmic acceleration [m s⁻²]
rho_bg = 1.0 / (4 * math.pi * G * t_H**2)  # background density [kg m⁻³]

# Convert user parameters to SI / consistent units
M_cluster = M_cluster_solar * M_sun
a_cluster = r_cluster_ly * ly_m
M_ellip   = M_ellip_solar   * M_sun
a_ellip   = r_ellip_ly      * ly_m
M_dwarf   = M_dwarf_solar   * M_sun
a_dwarf   = r_dwarf_ly      * ly_m

M_exp    = M_exp_solar  * M_sun
R_d_m    = R_d_ly       * ly_m
R_d_pc   = R_d_ly       * ly_pc

M_ser    = M_ser_solar  * M_sun
R_e_m    = R_e_ser_ly   * ly_m
R_e_pc   = R_e_ser_ly   * ly_pc
bn_ser   = gammaincinv(2 * n_ser, 0.5)

M_MN     = M_MN_solar * M_sun
a_MN_m   = a_MN_ly * ly_m
b_MN_m   = b_MN_ly * ly_m

# ════════════════════════════════════════════════════════════════════════════════
# ── HERNQUIST VELOCITY DISPERSION ──────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════

def _hernquist_enclosed(r_m, M, a):
    r = np.asarray(r_m, float)
    return M * r**2 / (r + a)**2

def _hernquist_rho(r_m, M, a):
    r = np.asarray(r_m, float)
    return (M * a) / (2 * np.pi * r * (r + a)**3)

def _rho_bg_at(r_m):
    """Background (universal) density at radius r."""
    return c**2 / (4 * np.pi * G * (R_H - np.asarray(r_m, float))**2)

def hernquist_newtonian(r_ly, M, a, n_grid=8000):
    """Pure Newtonian (no cosmic) Hernquist velocity dispersion [m/s]."""
    r_m = np.atleast_1d(r_ly) * ly_m
    r_min = max(1e-12 * a, 1.0)
    r_max = 2000.0 * a
    rg = np.logspace(np.log10(r_min), np.log10(r_max), n_grid)
    intgd = G * _hernquist_enclosed(rg, M, a) / rg**2
    cum = np.concatenate(([0.0], np.cumsum(0.5 * (intgd[1:] + intgd[:-1]) * np.diff(rg))))
    sigma_grid = np.sqrt(np.maximum((cum[-1] - cum) / (4 * np.pi), 0.0))
    return np.interp(r_m, rg, sigma_grid)

def hernquist_total(r_ly, M, a, n_grid=8000):
    """Total (Newtonian + cosmic) velocity dispersion [m/s]."""
    r_m = np.atleast_1d(r_ly) * ly_m
    r_min = max(1e-12 * a, 1.0)
    r_max = 2000.0 * a
    rg = np.logspace(np.log10(r_min), np.log10(r_max), n_grid)

    # Find flux-balance radius
    i_lim = np.argmin(np.abs(_hernquist_rho(rg, M, a)
                               - df * (M_env / M)**(1/3) * _rho_bg_at(rg)))
    rg = rg[:i_lim + 1]

    M_enc  = _hernquist_enclosed(rg, M, a)
    a_R_lo = c**2 / (R_H - rg)
    f      = np.maximum(0.0, 1 - _rho_bg_at(rg) / (df * _hernquist_rho(rg, M, a)))

    # Two auxiliary integrals (sigma^4 = (R_integral + a_R) * M_integral)
    intgd_M = G * M_enc / (4 * np.pi * rg)
    intgd_R = G * M_enc / (4 * np.pi * rg**3)
    def _cumrev(arr):
        dr = np.diff(rg)
        seg = 0.5 * (arr[1:] + arr[:-1]) * dr
        cum = np.concatenate(([0.0], np.cumsum(seg)))
        return cum[-1] - cum

    sigma_grid = (f * (_cumrev(intgd_R) + a_R_lo) * _cumrev(intgd_M))**0.25
    sigma_grid[-1] = 0.0
    return np.interp(r_m, rg, sigma_grid)

# ════════════════════════════════════════════════════════════════════════════════
# ── SPIRAL: EXPONENTIAL DISK ────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════

def _exp_enclosed_kg(r_ly):
    """Enclosed mass [kg] for exponential disk Σ = Σ₀ exp(-R/R_d)."""
    R_m = np.atleast_1d(r_ly) * ly_m
    x   = R_m / R_d_m
    Sigma0 = M_exp / (2 * math.pi * R_d_m**2)
    M_enc  = 2 * math.pi * Sigma0 * R_d_m**2 * (1 - (1 + x) * np.exp(-x))
    return np.maximum(M_enc, 0.0)

def exp_newtonian(r_ly):
    M_enc = _exp_enclosed_kg(r_ly)
    R_m   = np.atleast_1d(r_ly) * ly_m
    return np.sqrt(np.maximum(G * M_enc / R_m, 0.0))

def exp_total(r_ly):
    R_m   = np.maximum(np.atleast_1d(r_ly) * ly_m, 1.0)
    M_enc = _exp_enclosed_kg(r_ly)
    a_o   = G * M_enc / R_m**2
    rho_o = np.maximum(3 * M_enc / (4 * math.pi * R_m**3), 0.1 * rho_bg)
    f     = np.maximum(0.0, 1 - (M_env / M_exp)**(1/3) * rho_bg / (df * rho_o))
    a_R_l = c**2 / (R_H - R_m)
    return (f * (a_o + a_R_l / (2 * math.pi)) * G * M_enc)**0.25

# ════════════════════════════════════════════════════════════════════════════════
# ── SPIRAL: SÉRSIC ─────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════

def _sigma_sersic(r_pc):
    return np.exp(-bn_ser * ((np.maximum(r_pc, 1e-9) / R_e_pc)**(1 / n_ser) - 1))

def _sersic_enclosed_kg(r_ly):
    r_m  = np.atleast_1d(r_ly) * ly_m
    r_pc = r_m / pc_m
    sig  = _sigma_sersic(r_pc)
    intgd = 2 * math.pi * r_m * sig
    dr    = np.diff(r_m)
    M_raw = np.concatenate(([0.0], np.cumsum(0.5 * (intgd[1:] + intgd[:-1]) * dr)))
    return M_raw * (M_ser / M_raw[-1])

def sersic_newtonian(r_ly):
    M_enc = _sersic_enclosed_kg(r_ly)
    R_m   = np.atleast_1d(r_ly) * ly_m
    return np.sqrt(np.maximum(G * M_enc / R_m, 0.0))

def sersic_total(r_ly):
    R_m   = np.maximum(np.atleast_1d(r_ly) * ly_m, 1.0)
    M_enc = _sersic_enclosed_kg(r_ly)
    a_o   = G * M_enc / R_m**2
    rho_o = np.maximum(3 * M_enc / (4 * math.pi * R_m**3), 0.1 * rho_bg)
    f     = np.maximum(0.0, 1 - (M_env / M_ser)**(1/3) * rho_bg / (df * rho_o))
    a_R_l = c**2 / (R_H - R_m)
    return (f * (a_o + a_R_l / (2 * math.pi)) * G * M_enc)**0.25

# ════════════════════════════════════════════════════════════════════════════════
# ── SPIRAL: MIYAMOTO–NAGAI ─────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════

def mn_newtonian(r_ly):
    R_m    = np.maximum(np.atleast_1d(r_ly) * ly_m, 1.0)
    ab_m   = a_MN_m + b_MN_m
    denom  = (R_m**2 + ab_m**2)**1.5
    return np.sqrt(np.maximum(G * M_MN * R_m**2 / denom, 0.0))

def mn_total(r_ly):
    R_m  = np.maximum(np.atleast_1d(r_ly) * ly_m, 1.0)
    ab_m = a_MN_m + b_MN_m
    M_enc = M_MN * R_m**3 / (R_m**2 + ab_m**2)**1.5
    a_o  = G * M_enc / R_m**2
    rho_o = np.maximum(3 * M_enc / (4 * math.pi * R_m**3), 0.1 * rho_bg)
    f    = np.maximum(0.0, 1 - (M_env / M_MN)**(1/3) * rho_bg / (df * rho_o))
    a_R_l = c**2 / (R_H - R_m)
    return (f * (a_o + a_R_l / (2 * math.pi)) * G * M_enc)**0.25

# ════════════════════════════════════════════════════════════════════════════════
# ── COMPUTE PROFILES ───────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════

radii_ly = np.logspace(1, 9, 1000)

profiles = {}   # name → (total_km_s, newton_km_s, colour, label_total, label_newton)

if PLOT_CLUSTER:
    profiles["cluster"] = (
        hernquist_total(radii_ly, M_cluster, a_cluster) / 1e3,
        hernquist_newtonian(radii_ly, M_cluster, a_cluster) / 1e3,
        "blue", r"Cluster total $\sigma$", r"Cluster Newton $\sigma$",
    )

if PLOT_ELLIP:
    profiles["ellip"] = (
        hernquist_total(radii_ly, M_ellip, a_ellip) / 1e3,
        hernquist_newtonian(radii_ly, M_ellip, a_ellip) / 1e3,
        "green", r"Elliptical total $\sigma$", r"Elliptical Newton $\sigma$",
    )

if PLOT_DWARF:
    profiles["dwarf"] = (
        hernquist_total(radii_ly, M_dwarf, a_dwarf) / 1e3,
        hernquist_newtonian(radii_ly, M_dwarf, a_dwarf) / 1e3,
        "red", r"Dwarf total $\sigma$", r"Dwarf Newton $\sigma$",
    )

if PLOT_SPIRAL:
    _dispatch = {"exp": (exp_total, exp_newtonian),
                 "sersic": (sersic_total, sersic_newtonian),
                 "MN": (mn_total, mn_newtonian)}
    _fn_tot, _fn_new = _dispatch[SPIRAL_PROFILE]
    _label_map = {"exp": "Exp-disk", "sersic": "Sérsic", "MN": "Miyamoto–Nagai"}
    _lbl = _label_map[SPIRAL_PROFILE]
    profiles["spiral"] = (
        _fn_tot(radii_ly) / 1e3,
        _fn_new(radii_ly) / 1e3,
        "black", fr"Spiral total $v$ ({_lbl})", fr"Spiral Newton $v$ ({_lbl})",
    )

# ════════════════════════════════════════════════════════════════════════════════
# ── PLOT ───────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════

fig, ax = plt.subplots(figsize=(8, 7))

for key, (tot, new, col, lbl_tot, lbl_new) in profiles.items():
    ax.plot(radii_ly, tot, lw=3, color=col, label=lbl_tot)
    ax.plot(radii_ly, new, lw=1.5, ls="--", color=col, alpha=0.6, label=lbl_new)

# ── Observed data overlay ─────────────────────────────────────────────────────
if SHOW_DATA:
    _type_col = {"spiral": "black", "elliptical": "green",
                 "dwarf": "red", "cluster": "blue"}
    _type_match = {"cluster": PLOT_CLUSTER, "elliptical": PLOT_ELLIP,
                   "dwarf": PLOT_DWARF, "spiral": PLOT_SPIRAL}

    for gname, ginfo in GALAXY_DATA.items():
        gtype = ginfo["type"]
        # For spirals, only overlay the selected galaxy
        if gtype == "spiral" and gname != SPIRAL_DATA_GALAXY:
            continue
        if not _type_match.get(gtype, False):
            continue
        r_arr, v_arr = zip(*ginfo["data"])
        ax.scatter(r_arr, v_arr,
                   color=_type_col.get(gtype, "gray"),
                   marker="o", s=50, zorder=5,
                   label=fr"{gname} ({ginfo['ref']})")

# ── Axes ──────────────────────────────────────────────────────────────────────
ax.set_xlabel(r"$r$ (light-years)", fontsize=20)
ax.set_ylabel(r"$\sigma,\, v$ (km/s)", fontsize=20)
ax.set_xscale(XSCALE)
ax.set_yscale(YSCALE)
ax.set_xlim(XLIM)
ax.set_ylim(YLIM)
ax.tick_params(axis="both", which="major", labelsize=16)
ax.grid(True, which="both", ls="--", lw=0.5)
#ax.legend(fontsize=11, loc="best")
plt.tight_layout()

if FILENAME:
    plt.savefig(path + FILENAME, dpi=300, bbox_inches="tight")
    print(f"Saved: {FILENAME}")
plt.show()
# Out:
# Saved: TFFJ.jpg

# %%
#@title DENSITY & ACCELERATION PROFILES
import math, numpy as np, matplotlib.pyplot as plt
from scipy.special import gammaincinv

plt.rcParams['font.family'] = 'DejaVu Serif'

# ── CONFIG ────────────────────────────────────────────────────────────────────
PROFILE  = "Hernquist"   # "Hernquist" or "Sersic"
M_SOLAR  = 1e11
R_SCALE_LY = 10_000      # Hernquist scale radius [ly]
R_E_LY   = 12_000        # Sérsic effective radius [ly]
N_SER    = 1.0
XLIM     = (1e1, 1e7)
YLIM_RHO = (1e-30, 1e-16)
YLIM_ACC = (1e-10, 1e-8)
# ─────────────────────────────────────────────────────────────────────────────

G = 6.67430e-11; c = 299792458; M_sun = 1.98847e30
ly_m = 9.461e15; pc_m = 3.0857e16; ly_pc = 0.306601
t_H  = 13.8e9 * 365.25 * 24 * 3600
R_H  = c * t_H

M    = M_SOLAR * M_sun
a    = R_SCALE_LY * ly_m
Re_m = R_E_LY * ly_m
Re_pc= R_E_LY * ly_pc
bn   = gammaincinv(2 * N_SER, 0.5)

radii_ly = np.logspace(1, 9, 1000)
r_m      = radii_ly * ly_m

def rho_bg(r_m): return c**2 / (4*np.pi*G*(R_H - r_m)**2)
def acc_bg(r_m): return c**2 / (R_H - r_m)

if PROFILE == "Hernquist":
    rho_loc = (M * a) / (2*np.pi*r_m*(r_m + a)**3)
    M_enc   = M * r_m**2 / (r_m + a)**2
    acc_loc = G * M_enc / r_m**2
    lbl_rho, lbl_acc = "Hernquist density", "Hernquist acceleration"
else:
    # Sérsic projected surface density as a proxy for 3D density
    sig_e = 1.0
    Sigma  = sig_e * np.exp(-bn * ((radii_ly * ly_pc / Re_pc)**(1/N_SER) - 1))
    rho_loc = Sigma * M_sun / pc_m**2 * (M / (np.trapz(2*np.pi*r_m*Sigma, r_m)))
    dr     = np.diff(r_m)
    intgd  = 2*np.pi*r_m*rho_loc
    M_cum  = np.concatenate(([0.], np.cumsum(0.5*(intgd[1:]+intgd[:-1])*dr)))
    M_enc  = M_cum * M / M_cum[-1]
    acc_loc = G * M_enc / r_m**2
    lbl_rho, lbl_acc = "Sérsic density (proxy)", "Sérsic acceleration (2D)"

fig, ax1 = plt.subplots(figsize=(8, 7))
ax1.loglog(radii_ly, rho_loc, lw=2, color="blue",  label=lbl_rho)
ax1.loglog(radii_ly, rho_bg(r_m), lw=4, color="black", label="Background density")
ax1.set_xlabel(r"$r$ (light-years)", fontsize=20)
ax1.set_ylabel("Density (kg m⁻³)", color="blue", fontsize=20)
ax1.set_xlim(XLIM); ax1.set_ylim(YLIM_RHO)
ax1.tick_params(axis="y", labelcolor="blue", labelsize=14)
ax1.tick_params(axis="x", labelsize=14)
ax1.grid(True, which="both", ls="--", lw=0.5)

ax2 = ax1.twinx()
ax2.loglog(radii_ly, acc_loc,    lw=2, ls="--", color="red",   label=lbl_acc)
ax2.loglog(radii_ly, acc_bg(r_m),lw=4, ls="--", color="black", label="Background acceleration")
ax2.set_ylabel("Acceleration (m s⁻²)", color="red", fontsize=20)
ax2.set_ylim(YLIM_ACC)
ax2.tick_params(axis="y", labelcolor="red", labelsize=14)

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()
ax1.legend(h1 + h2, l1 + l2, fontsize=12, loc="lower left")
plt.tight_layout(); plt.show()

# %%
#@title FLUX-BALANCE OVERDENSITY
import numpy as np, math, matplotlib.pyplot as plt

G = 6.67430e-11; c = 299792458; M_sun = 1.98847e30
t_H  = 13.8e9 * 365.25 * 24 * 3600
rho  = 1/(4*math.pi*G*t_H**2)
M    = 1e11 * M_sun
r_fb = (M / rho)**(1/3)

xi = np.linspace(0, 5, 1000)
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 10), sharex=False)
for ax, xs, kw in [(ax1, "linear", {}), (ax2, "log", {"xscale": "log"})]:
    ax.plot(xi, 1 - xi**3,                label=r"$1-(r/r_{fb})^3$",             lw=2)
    ax.plot(xi, 1/(1+xi**3)**2, "--",     label=r"$1/(1+(r/r_{fb})^3)^2$",       lw=2)
    ax.plot(xi, 1/(1+xi**3),    ":",      label=r"$1/(1+(r/r_{fb})^3)$",          lw=2)
    ax.axvline(1, color="gray", lw=2, ls="--", label=r"$r=r_{fb}$")
    ax.axhline(0, color="gray", lw=2, ls="--")
    ax.set_xlabel(r"$r/r_{fb}$" + (" (log)" if xs=="log" else ""), fontsize=13)
    ax.set_ylabel(r"$\delta_\rho$", fontsize=13)
    ax.set_ylim(-1.1, 1.2); ax.legend(); ax.grid(True)
    if xs == "log": ax.set_xscale("log"); ax.set_xlim(0.1, 10)
    else: ax.set_xlim(0, 2)
plt.tight_layout(); plt.show()

# %%
#@title DENSITIES ACROSS THE COSMOS
import numpy as np, matplotlib.pyplot as plt
from matplotlib.ticker import LogLocator

plt.rcParams['font.family'] = 'DejaVu Serif'

G = 6.67430e-11; c = 299792458
year = 365.25 * 24 * 3600; ly_m = 9.461e15

objects = {
    "Stellar black hole": 1e18, "Neutron star": 1e17, "White dwarf": 1e9,
    "Sun": 1.41e3,              "Red dwarf": 1e2,     "Giant star": 1e-5,
    "Little Red Dot": 1e-15,   "Globular cluster": 1e-17,
    "Dwarf galaxy": 1e-20,     "Spiral galaxy": 1e-21,
    "Elliptical galaxy": 1e-22,"Ultra-diffuse galaxy": 1e-23,
    "Galaxy group": 1e-24,     "Galaxy cluster": 1e-25,
    "Supercluster": 1e-26,
}

rho_arr = np.logspace(-27, 19, 500)
t_arr   = np.sqrt(1 / (4*np.pi*G*rho_arr)) / year

rho_pts = np.array(list(objects.values()))
t_pts   = np.sqrt(1 / (4*np.pi*G*rho_pts)) / year

fig, ax = plt.subplots(figsize=(8, 6))
ax.loglog(rho_arr, t_arr, lw=1, color="gray",
           label=r"$t=(4\pi G\rho)^{-1/2}$")
ax.scatter(rho_pts, t_pts, color="white", edgecolor="black", s=80, zorder=5)
for name, x, y in zip(objects.keys(), rho_pts, t_pts):
    ax.annotate(name, (x, y), xytext=(6, -4), textcoords="offset points",
                ha="left", fontsize=7.5)
ax.set_xlabel(r"$\rho$ (kg m⁻³)", fontsize=16)
ax.set_ylabel(r"$t$ (years)", fontsize=16)
ax.set_xlim(1e-33, 1e19); ax.set_ylim(1e-15, 1e12)
ax.invert_xaxis()
ax.xaxis.set_major_locator(LogLocator(numticks=10))
ax.yaxis.set_major_locator(LogLocator(numticks=10))
ax.grid(True, which="both", ls="--", lw=0.5)
ax.legend(fontsize=11)
plt.tight_layout()
plt.savefig("cosmic_densities.jpg", dpi=300, bbox_inches="tight")
plt.show()

# %%
#@title PANTHEON+ TYPE Ia SUPERNOVA HUBBLE DIAGRAM
# Annila & Wikstrom (2022) Frontiers in Physics — updated with Pantheon+ (Brout et al. 2022 Scolnic et al. 2022)
#
# Luminosity distance (AW Eq. 24):
#   D_L = R * z * sqrt(1+z)
# where R = c*t0  (present causal radius), t0 = age of universe.
#
# Distance modulus:
#   mu = 5*log10(D_L / 10 pc)
#      = 5*log10(z) + 2.5*log10(1+z) + K
# where  K = 5*log10(R / 10 pc) = 5*log10(c*t0 / 10 pc)
# is a PHYSICAL constant set by t0 (the only free parameter).
# The 5*log10(1+z) term mentioned in the paper is the redshift correction
# that when combined with the -2.5*log10(1+z) from D_L = R*z/sqrt(1+z)
# yields the net +2.5*log10(1+z) used here.
#
# The LCDM prediction uses flat FLRW with (Omega_m, Omega_L) = (0.3, 0.7).

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad
from scipy.stats import binned_statistic
from matplotlib.ticker import MultipleLocator
import urllib.request

plt.rcParams["font.family"] = "DejaVu Serif"

# ── CONFIGURATION ─────────────────────────────────────────────────────────────
t0_Gyr = 13.8          # age of universe [Gyr] — adjust within 13.0–14.4 for leeway
Om     = 0.30          # Omega_matter (LCDM comparison only)
OL     = 0.70          # Omega_Lambda (LCDM comparison only)
H0_LCDM = 73.0         # km/s/Mpc    (LCDM comparison only)
c_km   = 2.998e5       # speed of light [km/s]

SAVE_FIGURE = True    # True requires Drive mounted (Cell 1)
path     = "/content/gdrive/MyDrive/ColabMaps/"
filename = "pantheon_plus_hubble.jpg"

# ── DERIVED CONSTANTS ─────────────────────────────────────────────────────────
km_to_Mpc = 1.0 / 3.0857e19          # 1 km = this many Mpc
t0_s      = t0_Gyr * 1e9 * 365.25 * 24 * 3600
H0_AW     = 1.0 / t0_s / km_to_Mpc  # H0 = 1/t0  [km/s/Mpc]
R_Mpc     = c_km / H0_AW             # causal radius [Mpc]
R_pc      = R_Mpc * 1e6              # causal radius [pc]
mu_R       = 5.0 * np.log10(R_pc / 10.0)   # physical calibration constant
print(f"t0 = {t0_Gyr} Gyr  →  H0 = {H0_AW:.1f} km/s/Mpc,  R = {R_Mpc:.0f} Mpc,  K = {mu_R:.4f}")

# ── ANNILA-WIKSTROM PREDICTION ────────────────────────────────────────────────
def mu_aw(z):
    """AW distance modulus: 5.0 * np.log10(R_pc / 10.0)+5logz−2.5log(1+z)+K, where K=5log(1+z)"""
    return 5.0*np.log10(z) + 2.5*np.log10(1.0+z) + mu_R

# ── LCDM PREDICTION ───────────────────────────────────────────────────────────
def mu_lcdm(z):
    """Flat LCDM distance modulus."""
    dc = c_km/H0_LCDM * quad(
        lambda zp: 1.0/np.sqrt(Om*(1+zp)**3 + OL), 0, z
    )[0]
    return 5.0*np.log10(dc*(1+z)*1e6/10.0)

# Einstein–de Sitter (flat, matter-only, no dark energy): Omega_m=1, Omega_L=0
def mu_eds(z, H0=H0_LCDM):
    DL = 2*c_km/H0 * np.sqrt(1+z) * (np.sqrt(1+z) - 1)  # Mpc
    return 5*np.log10(DL * 1e6 / 10)                       # convert to pc

# ── DOWNLOAD PANTHEON+ DATA ───────────────────────────────────────────────────
print("Downloading Pantheon+ (Scolnic et al. 2022)...")
url = ("https://raw.githubusercontent.com/PantheonPlusSH0ES/DataRelease/"
       "main/Pantheon+_Data/4_DISTANCES_AND_COVAR/Pantheon+SH0ES.dat")
with urllib.request.urlopen(url) as r:
    raw = r.read().decode()

lines  = raw.strip().split("\n")
header = lines[0].split()
rows   = [l.split() for l in lines[1:]]
col    = {h: i for i, h in enumerate(header)}

zHD    = np.array([float(row[col["zHD"]])               for row in rows])
mu_obs = np.array([float(row[col["MU_SH0ES"]])          for row in rows])
mu_err = np.array([float(row[col["MU_SH0ES_ERR_DIAG"]]) for row in rows])
is_cal = np.array([int(  row[col["IS_CALIBRATOR"]])      for row in rows])
cid    = np.array([       row[col["CID"]]                for row in rows])

# Cosmology sample: non-calibrators, z > 0.01, deduplicated
mask   = (is_cal == 0) & (zHD > 0.01)
zHD    = zHD[mask];    mu_obs = mu_obs[mask]
mu_err = mu_err[mask]; cid    = cid[mask]
_, keep = np.unique(cid, return_index=True)
zHD    = zHD[keep];    mu_obs = mu_obs[keep]; mu_err = mu_err[keep]
print(f"  {len(zHD)} unique SNe Ia,  z = {zHD.min():.4f} – {zHD.max():.4f}")

# ── BIN THE DATA ──────────────────────────────────────────────────────────────
z_edges = np.logspace(np.log10(0.015), np.log10(2.4), 26)
z_cen   = 0.5*(z_edges[1:] + z_edges[:-1])
mu_bin, _, _  = binned_statistic(zHD, mu_obs, "median", bins=z_edges)
err_bin, _, _ = binned_statistic(zHD, mu_err, "mean",   bins=z_edges)
n_bin, _, _   = binned_statistic(zHD, zHD,    "count",  bins=z_edges)
good = ~np.isnan(mu_bin) & (n_bin >= 3)

# ── SMOOTH THEORY CURVES ──────────────────────────────────────────────────────
z_th       = np.logspace(np.log10(0.012), np.log10(2.4), 500)
mu_th_aw   = mu_aw(z_th)
mu_th_lcdm = np.array([mu_lcdm(zi) for zi in z_th])
mu_th_eds  = mu_eds(z_th)

# ── RESIDUALS AT DATA POINTS ──────────────────────────────────────────────────
res_aw   = mu_obs - mu_aw(zHD)
res_lcdm = mu_obs - np.array([mu_lcdm(zi) for zi in zHD])
res_eds  = mu_obs - mu_eds(zHD)

res_aw_bin,   _, _ = binned_statistic(zHD, res_aw,   "median", bins=z_edges)
res_lcdm_bin, _, _ = binned_statistic(zHD, res_lcdm, "median", bins=z_edges)
re_err_bin,   _, _ = binned_statistic(zHD, mu_err,   "mean",   bins=z_edges)
res_eds_bin,  _, _ = binned_statistic(zHD, res_eds, "median", bins=z_edges)

# ── PLOT ──────────────────────────────────────────────────────────────────────
fig, axes = plt.subplots(2, 1, figsize=(9, 12),
                         gridspec_kw={"height_ratios": [3, 1.6]},
                         sharex=True)
fig.subplots_adjust(hspace=0.06)

# — Hubble diagram —
ax = axes[0]
ax.scatter(zHD, mu_obs, s=2, color="black", alpha=0.35, zorder=1,
           label="Pantheon+ SNe Ia  (1466)")
ax.errorbar(z_cen[good], mu_bin[good], yerr=err_bin[good],
            fmt="o", ms=5.5, color="black", elinewidth=1.2, capsize=2.5,
            zorder=3, label=r"Binned median $\pm$ mean $\sigma$")
ax.plot(z_th, mu_th_lcdm, color="black", ls=":",  lw=2.5, zorder=4,
        label=r"$\Lambda$CDM  ($\Omega_m{=}0.3,\;\Omega_\Lambda{=}0.7,\;H_0{=}73$)")
ax.plot(z_th, mu_th_aw,   color="red", ls="--", lw=2.5, zorder=4,
        label=(rf"Annila–Wikström:  $\mu=5\log_{{10}}[z\sqrt{{1+z}}]+K$"
               rf"  ($t_0={t0_Gyr}$ Gyr)"))
# In the Hubble diagram plot, add:
ax.plot(z_th, mu_th_eds, color="black", ls="-", lw=1.5, zorder=4,
        label=r"Einstein–de Sitter  ($\Omega_m{=}1,\;\Omega_\Lambda{=}0$)")

#ax.set_ylabel(r"Distance modulus  $\mu$", fontsize=15)
ax.set_ylabel(r"$\mu$", fontsize=18)
ax.set_xscale("log")
ax.set_xlim(0.012, 2.6)
ax.set_ylim(33.5, 47)
ax.tick_params(labelsize=15)
#ax.legend(fontsize=11.5, loc="upper left", framealpha=0.9)
ax.grid(True, which="both", ls="--", lw=0.4, alpha=0.5)
#ax.set_title(
#    rf"Pantheon+ Hubble diagram  —  $K = 5\log_{{10}}(ct_0/10\,\mathrm{{pc}}) = {mu_R:.3f}$",
#    fontsize=13)


# — Residuals —
ax2 = axes[1]
ax2.axhline(0, color="k", lw=1.8, label=r"zero line")
ax2.scatter(zHD, res_lcdm, s=2, color="black", alpha=0.25, zorder=1)
ax2.errorbar(z_cen[good], res_lcdm_bin[good], yerr=re_err_bin[good],
             fmt="o", ms=5, color="k", elinewidth=1.2, capsize=2.5, zorder=3,
             label=r"$\Lambda$CDM  residuals")
ax2.scatter(zHD, res_aw, s=2, color="black", alpha=0.25, zorder=1)
ax2.errorbar(z_cen[good], res_aw_bin[good], yerr=re_err_bin[good],
             fmt="s", ms=5, color="red", elinewidth=1.2, capsize=2.5, zorder=3,
             label="AW residuals")
#ax2.scatter(zHD, res_eds, s=2, color="palegreen", alpha=0.25, zorder=1)
#ax2.errorbar(z_cen[good], res_eds_bin[good], yerr=re_err_bin[good],
#             fmt="^", ms=5, color="forestgreen", elinewidth=1.2, capsize=2.5,
#             zorder=3, label="EdS residuals")

ax2.set_xlabel(r"$z$", fontsize=15)
ax2.set_ylabel(r"$\mu_\mathrm{obs}-\mu_\mathrm{model}$", fontsize=18)
ax2.set_ylim(-1.0, 1.0)
# Major tick labels
ax2.yaxis.set_major_locator(MultipleLocator(0.5))
# Minor ticks for the extra grid lines
ax2.yaxis.set_minor_locator(MultipleLocator(0.25))
ax2.grid(True, which="both", ls="--", lw=0.4, alpha=0.5)
ax2.tick_params(labelsize=15)
#ax2.legend(fontsize=11, loc="upper left", ncol=2, framealpha=0.9)
ax2.grid(True, which="both", ls="--", lw=0.4, alpha=0.5)

plt.tight_layout()
if SAVE_FIGURE:
    plt.savefig(path + filename, dpi=300, bbox_inches="tight")
    print(f"Saved: {filename}")
plt.show()

# ── STATISTICS ────────────────────────────────────────────────────────────────
print()
print(f"Residual statistics ({len(zHD)} SNe, diagonal errors only):")
print(f"  LCDM   mean = {res_lcdm.mean():+.3f}  std = {res_lcdm.std():.3f} mag")
print(f"  AW     mean = {res_aw.mean():+.3f}  std = {res_aw.std():.3f} mag")
print()
print(f"AW vs LCDM offset at key redshifts (t0 = {t0_Gyr} Gyr):")
for z in [0.1, 0.3, 0.5, 1.0, 1.5, 2.0]:
    print(f"  z = {z:.1f}:  Delta_mu = {mu_aw(z)-mu_lcdm(z):+.3f} mag")
print()
print("Tip: adjust t0_Gyr (13.0–14.4) to shift the AW curve vertically.")
print("     The redshift dependence 5*log10(z) + 2.5*log10(1+z) is fixed by theory.")
# Out:
# t0 = 13.8 Gyr  →  H0 = 70.9 km/s/Mpc,  R = 4231 Mpc,  K = 43.1323
# ...
#   1466 unique SNe Ia,  z = 0.0102 – 2.2614
# Saved: pantheon_plus_hubble.jpg
# Residual statistics (1466 SNe, diagonal errors only):
#   LCDM   mean = -0.010  std = 0.154 mag
#   AW     mean = +0.016  std = 0.159 mag
#
# AW vs LCDM offset at key redshifts (t0 = 13.8 Gyr):
#   z = 0.1:  Delta_mu = +0.012 mag
#   z = 0.3:  Delta_mu = -0.062 mag
#   z = 0.5:  Delta_mu = -0.103 mag
#   z = 1.0:  Delta_mu = -0.124 mag
#   z = 1.5:  Delta_mu = -0.090 mag
#   z = 2.0:  Delta_mu = -0.036 mag
#
# Tip: adjust t0_Gyr (13.0–14.4) to shift the AW curve vertically.
#      The redshift dependence 5*log10(z) + 2.5*log10(1+z) is fixed by theory.
